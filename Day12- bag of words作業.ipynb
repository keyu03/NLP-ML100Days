# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2351個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n 
    index_word[n] = word
    n+=1

# %%
word_index
# Out:
# {'tastings': 0,
#  'refried': 1,
#  'six': 2,
#  '3': 3,
#  'marrow': 4,
#  'fondue': 5,
#  'Awful': 6,
#  'watered': 7,
#  'article': 8,
#  'topic': 9,
#  'finish': 10,
#  'Update': 11,
#  'venturing': 12,
#  'Terrible': 13,
#  'moist': 14,
#  'temp.I': 15,
#  'Coffee': 16,
#  'strip': 17,
#  'dishes': 18,
#  'front': 19,
#  'generic': 20,
#  'double': 21,
#  'needs': 22,
#  'spaghetti': 23,
#  'easily': 24,
#  'refill': 25,
#  'fell': 26,
#  'feel': 27,
#  'tiramisu': 28,
#  'few': 29,
#  'sitting': 30,
#  'clue': 31,
#  'disgusted': 32,
#  'screwed': 33,
#  'delicious': 34,
#  'everyone': 35,
#  'The': 36,
#  'pub': 37,
#  'Bloody': 38,
#  'please': 39,
#  'Elk': 40,
#  'Sunday': 41,
#  'guys': 42,
#  'bill': 43,
#  'eating': 44,
#  'hated': 45,
#  'dealing': 46,
#  'sause': 47,
#  'point': 48,
#  'use': 49,
#  'Chipotle': 50,
#  'covers': 51,
#  'theft': 52,
#  'disgusting': 53,
#  'That': 54,
#  'charcoal': 55,
#  'gone': 56,
#  'surprised': 57,
#  'spicy': 58,
#  'Based': 59,
#  'Valley': 60,
#  'modern': 61,
#  'untoasted': 62,
#  'mushrooms': 63,
#  'beers': 64,
#  'very': 65,
#  'Burrittos': 66,
#  'falling': 67,
#  'leftover': 68,
#  'like': 69,
#  'loudly': 70,
#  'started': 71,
#  'buffets': 72,
#  'how': 73,
#  'wonderful': 74,
#  'healthy': 75,
#  'airline': 76,
#  'any': 77,
#  'brisket': 78,
#  'times': 79,
#  'tolerance': 80,
#  'talk': 81,
#  'number': 82,
#  'looking': 83,
#  'thanks': 84,
#  'Frozen': 85,
#  'yucky': 86,
#  'fill': 87,
#  'welcome': 88,
#  'Mango': 89,
#  'thought': 90,
#  'case': 91,
#  'seriously': 92,
#  'Favorite': 93,
#  'awful': 94,
#  'shocked': 95,
#  'satifying': 96,
#  'once': 97,
#  'lived': 98,
#  'really': 99,
#  'fry': 100,
#  'never': 101,
#  'ravoli': 102,
#  'fact': 103,
#  'bite': 104,
#  'wow': 105,
#  'small': 106,
#  'bamboo': 107,
#  'Yeah': 108,
#  'two': 109,
#  'yukon': 110,
#  "'d": 111,
#  'hours': 112,
#  'wrong': 113,
#  'cut': 114,
#  'read': 115,
#  'EVER': 116,
#  'stood': 117,
#  'doubt': 118,
#  'this': 119,
#  'Joey': 120,
#  'Waiter': 121,
#  'cashew': 122,
#  'most': 123,
#  'three': 124,
#  'options': 125,
#  'occasions': 126,
#  'saving': 127,
#  'highlight': 128,
#  'relaxed': 129,
#  'heads': 130,
#  'us': 131,
#  'ahead': 132,
#  'bowl': 133,
#  'looked': 134,
#  'Bean': 135,
#  'ways': 136,
#  'course': 137,
#  'latte': 138,
#  'STEP': 139,
#  'neighborhood': 140,
#  'service': 141,
#  'martini': 142,
#  'list': 143,
#  'bring': 144,
#  'thin': 145,
#  'people': 146,
#  'filling': 147,
#  'refused': 148,
#  'yourself': 149,
#  'mom': 150,
#  'meat': 151,
#  'rib': 152,
#  'returning': 153,
#  'pita': 154,
#  'memory': 155,
#  'trying': 156,
#  'worst': 157,
#  'Tasted': 158,
#  '.....': 159,
#  'those': 160,
#  'patio': 161,
#  'owner': 162,
#  'larger': 163,
#  'shops': 164,
#  'sound': 165,
#  'consistent': 166,
#  'tongue': 167,
#  'accountant': 168,
#  'Crust': 169,
#  'There': 170,
#  'Everyone': 171,
#  'overcooked': 172,
#  'pretty': 173,
#  'set': 174,
#  'just': 175,
#  'AZ': 176,
#  'parties': 177,
#  'blame': 178,
#  'ask': 179,
#  'last': 180,
#  'despicable': 181,
#  'towards': 182,
#  'fun': 183,
#  'consider': 184,
#  'honestly': 185,
#  'vain': 186,
#  'arepas': 187,
#  'fireball': 188,
#  'Seafood': 189,
#  'sorely': 190,
#  'business': 191,
#  'Blah': 192,
#  'i': 193,
#  '-': 194,
#  'trips': 195,
#  'sexy': 196,
#  'Philadelphia': 197,
#  'Waited': 198,
#  'southwest': 199,
#  'prefer': 200,
#  'San': 201,
#  'stuff': 202,
#  'car': 203,
#  'entrees': 204,
#  'many': 205,
#  'regularly': 206,
#  'songs': 207,
#  'hospitality': 208,
#  'girlfriend': 209,
#  'daily': 210,
#  'trap': 211,
#  'WILL': 212,
#  'Both': 213,
#  'sushi': 214,
#  'Frenchman': 215,
#  'Damn': 216,
#  'mistake': 217,
#  'pissd': 218,
#  'cause': 219,
#  'rapidly': 220,
#  'Stopped': 221,
#  'quit': 222,
#  'bye': 223,
#  'food': 224,
#  'melted': 225,
#  'than': 226,
#  'jerk': 227,
#  'gloves.Everything': 228,
#  'item': 229,
#  'bathrooms': 230,
#  'tater': 231,
#  'Hut': 232,
#  'grease': 233,
#  'dead': 234,
#  'what': 235,
#  'thrilled': 236,
#  'bits': 237,
#  'whether': 238,
#  'pleasure': 239,
#  'yellow': 240,
#  'jalapeno': 241,
#  'tomato': 242,
#  'Cartel': 243,
#  "'s": 244,
#  'smaller': 245,
#  'price': 246,
#  'typical': 247,
#  'saying': 248,
#  'Same': 249,
#  'pleased': 250,
#  'Breeze': 251,
#  'charge': 252,
#  '30s': 253,
#  'Long': 254,
#  'law': 255,
#  'guests': 256,
#  'ESTABLISHMENT': 257,
#  'Highly': 258,
#  'sangria': 259,
#  'definitely': 260,
#  'killer': 261,
#  'Each': 262,
#  'Although': 263,
#  'terrible': 264,
#  'every': 265,
#  'Mary': 266,
#  'puree': 267,
#  'menus': 268,
#  'dough': 269,
#  'Boy': 270,
#  'vomited': 271,
#  'Gringos': 272,
#  'Camelback': 273,
#  'kid': 274,
#  'Just': 275,
#  'milkshake': 276,
#  'both': 277,
#  'flat-lined': 278,
#  'reviewing': 279,
#  'highly': 280,
#  'giving': 281,
#  'auju': 282,
#  'rate': 283,
#  'Heimer': 284,
#  'seal': 285,
#  'Things': 286,
#  'Stars': 287,
#  'melt': 288,
#  'violinists': 289,
#  'refreshing': 290,
#  'prime': 291,
#  'egg': 292,
#  'shawarrrrrrma': 293,
#  'months': 294,
#  'anyone': 295,
#  'Large': 296,
#  'classics': 297,
#  'solidify': 298,
#  'boy': 299,
#  'held': 300,
#  'Cape': 301,
#  'waste': 302,
#  'Lordy': 303,
#  'Come': 304,
#  'platter': 305,
#  'PERFECT': 306,
#  'coffee': 307,
#  'Gave': 308,
#  'excellent': 309,
#  'pop': 310,
#  'gyro': 311,
#  'apology': 312,
#  'Mmmm': 313,
#  'give': 314,
#  'Company': 315,
#  'human': 316,
#  'wants': 317,
#  'wish': 318,
#  'writing': 319,
#  'enthusiastic': 320,
#  'disrespected': 321,
#  'customer': 322,
#  'worker': 323,
#  'Palm': 324,
#  'slow': 325,
#  'servers': 326,
#  'shower': 327,
#  'joint': 328,
#  'surprise': 329,
#  'book': 330,
#  'me': 331,
#  ',': 332,
#  'beat': 333,
#  'tapas': 334,
#  'dont': 335,
#  'sucker': 336,
#  'nothing': 337,
#  'new': 338,
#  'felt': 339,
#  'BBQ': 340,
#  'Dessert': 341,
#  'used': 342,
#  'hummus': 343,
#  'Any': 344,
#  'No': 345,
#  'judge': 346,
#  'inviting': 347,
#  'gas': 348,
#  'gave': 349,
#  'itself': 350,
#  'hard': 351,
#  'LOVED': 352,
#  'stomach': 353,
#  'rare': 354,
#  '100': 355,
#  'fluffy': 356,
#  '*': 357,
#  'ache': 358,
#  'awkwardly': 359,
#  'living': 360,
#  'tenders': 361,
#  'owner/chef': 362,
#  'vegetarian': 363,
#  'serve': 364,
#  'baklava': 365,
#  'ridiculous': 366,
#  'humiliated': 367,
#  'Cibo': 368,
#  'because': 369,
#  'summary': 370,
#  'enjoyable': 371,
#  'spotty': 372,
#  'Bouchon': 373,
#  'unique': 374,
#  'absolutley': 375,
#  'craving': 376,
#  'forty': 377,
#  'outstanding': 378,
#  'lawyers': 379,
#  'reviewer': 380,
#  'ca': 381,
#  'Grill': 382,
#  'always': 383,
#  'succulent': 384,
#  'informative': 385,
#  'fan': 386,
#  'pile': 387,
#  'Then': 388,
#  'overhaul': 389,
#  'get': 390,
#  'suggestions': 391,
#  'Jenni': 392,
#  'Extremely': 393,
#  'Salad': 394,
#  'connoisseur': 395,
#  'wave': 396,
#  'glad': 397,
#  'Casino': 398,
#  'deliciously': 399,
#  'instead': 400,
#  'Soi': 401,
#  'onion': 402,
#  'array': 403,
#  'disgrace': 404,
#  'attentive': 405,
#  'slaw': 406,
#  'Baba': 407,
#  'North': 408,
#  'climbing': 409,
#  'found': 410,
#  'frustrated': 411,
#  'Have': 412,
#  'ten': 413,
#  'hereas': 414,
#  'Kind': 415,
#  'staying': 416,
#  'Bellagio': 417,
#  'fav': 418,
#  'Mellow': 419,
#  'sashimi': 420,
#  'banana': 421,
#  'said': 422,
#  'blanket': 423,
#  'located': 424,
#  'lunch': 425,
#  'listed': 426,
#  'chef': 427,
#  'Tonight': 428,
#  "'re": 429,
#  'warm': 430,
#  'trimmed': 431,
#  'worth': 432,
#  'MANAGEMENT': 433,
#  'Tried': 434,
#  'cranberry': 435,
#  'inexpensive': 436,
#  'correct': 437,
#  'WAY': 438,
#  'hit': 439,
#  'Ironman': 440,
#  '15': 441,
#  'side': 442,
#  'UNREAL': 443,
#  'Gold': 444,
#  'Edinburgh': 445,
#  'Mirage': 446,
#  'AVOID': 447,
#  'be': 448,
#  'also': 449,
#  'yellowtail': 450,
#  'freaking': 451,
#  'All': 452,
#  'seasoning': 453,
#  'Food': 454,
#  'there': 455,
#  'dirt': 456,
#  'WHAT': 457,
#  'forgetting': 458,
#  'Coming': 459,
#  'Rock': 460,
#  'reasons': 461,
#  'trippy': 462,
#  'plate': 463,
#  'effort': 464,
#  'Nobu': 465,
#  'generous': 466,
#  'tough': 467,
#  'plus': 468,
#  'Left': 469,
#  'treat': 470,
#  'Buffet': 471,
#  'Wow': 472,
#  'afternoon': 473,
#  'stir': 474,
#  'sit-down': 475,
#  'style': 476,
#  'taco': 477,
#  'rowdy': 478,
#  'avocado': 479,
#  'Sushi': 480,
#  'would': 481,
#  'since': 482,
#  'saffron': 483,
#  'dripping': 484,
#  'As': 485,
#  'HAPPENED': 486,
#  'juice': 487,
#  '23': 488,
#  'feels': 489,
#  'yay': 490,
#  'all': 491,
#  'themselves': 492,
#  'eel': 493,
#  'here': 494,
#  'back': 495,
#  'try': 496,
#  'takeout': 497,
#  'FREEZING': 498,
#  'close': 499,
#  'Bad': 500,
#  'lukewarm': 501,
#  'sugar': 502,
#  'nachos': 503,
#  'plastic': 504,
#  'margaritas': 505,
#  'shrimp': 506,
#  'Disappointing': 507,
#  'quick': 508,
#  'considering': 509,
#  'skimp': 510,
#  'vibe': 511,
#  'palate': 512,
#  'legs': 513,
#  'opinion': 514,
#  'High-quality': 515,
#  'Eggplant': 516,
#  'awesome': 517,
#  'cramming': 518,
#  'via': 519,
#  'WAAAAAAyyyyyyyyyy': 520,
#  'smelled': 521,
#  'My': 522,
#  'boyfriend': 523,
#  'Burger': 524,
#  'Indian': 525,
#  'life': 526,
#  'stop': 527,
#  'fries': 528,
#  'lost': 529,
#  'voted': 530,
#  'Sun': 531,
#  'club': 532,
#  'steakhouse': 533,
#  'priced': 534,
#  'meet': 535,
#  'Everything': 536,
#  'needed': 537,
#  'real': 538,
#  'donut': 539,
#  'extraordinary': 540,
#  'wontons': 541,
#  'mediocre': 542,
#  'Mexican': 543,
#  '70+': 544,
#  'attitudes': 545,
#  'relleno': 546,
#  'way': 547,
#  'myself': 548,
#  'lightly': 549,
#  'friend': 550,
#  'ensued': 551,
#  'You': 552,
#  'buffet': 553,
#  'Eve': 554,
#  'they': 555,
#  'Magazine': 556,
#  'interesting': 557,
#  'sense': 558,
#  'diverse': 559,
#  'shall': 560,
#  'guacamole': 561,
#  'crusty': 562,
#  'neat': 563,
#  'pack': 564,
#  'stay': 565,
#  'menu': 566,
#  'nay': 567,
#  'neither': 568,
#  'businesses': 569,
#  'Despite': 570,
#  'convenient': 571,
#  'lil': 572,
#  'brings': 573,
#  'single': 574,
#  'particular': 575,
#  'recommend': 576,
#  'wings': 577,
#  'burned': 578,
#  'exceeding': 579,
#  'poorly': 580,
#  'Def': 581,
#  'building': 582,
#  'flavorless': 583,
#  'Caballero': 584,
#  'Be': 585,
#  'hankering': 586,
#  'gluten': 587,
#  'oil': 588,
#  'know': 589,
#  'Thai': 590,
#  'each': 591,
#  'Hawaiian': 592,
#  'Filet': 593,
#  'raspberry': 594,
#  'prepared': 595,
#  'others': 596,
#  'Pho': 597,
#  'foods': 598,
#  'profiterole': 599,
#  'chip': 600,
#  'are': 601,
#  'atmosphere.1': 602,
#  'prices': 603,
#  'do': 604,
#  'drive': 605,
#  'packed': 606,
#  'sick': 607,
#  'recall': 608,
#  'kitchen': 609,
#  'late': 610,
#  'edible': 611,
#  'andddd': 612,
#  'covered': 613,
#  'dispenser': 614,
#  'APPETIZERS': 615,
#  'WASTE': 616,
#  'avoid': 617,
#  'hungry': 618,
#  '40': 619,
#  'Kabuki': 620,
#  'mesquite': 621,
#  'Why': 622,
#  'constructed': 623,
#  'believe': 624,
#  'tuna': 625,
#  'away': 626,
#  'drag': 627,
#  'Cant': 628,
#  'disappointing': 629,
#  'multiple': 630,
#  'This': 631,
#  '.': 632,
#  'barely': 633,
#  'heard': 634,
#  'amazing': 635,
#  'class': 636,
#  'part': 637,
#  'shirt': 638,
#  'Maybe': 639,
#  'crispy': 640,
#  'incredible': 641,
#  'Your': 642,
#  'rinse': 643,
#  'terrific': 644,
#  'store': 645,
#  'cheek': 646,
#  'perfection': 647,
#  'good': 648,
#  'outta': 649,
#  'Bland': 650,
#  'under-services': 651,
#  'eggplant': 652,
#  'selections': 653,
#  'Ambience': 654,
#  'non-fancy': 655,
#  'station': 656,
#  'boot': 657,
#  'subpar': 658,
#  'Tigerlilly': 659,
#  'grow': 660,
#  'reasonably': 661,
#  'wait': 662,
#  'Rick': 663,
#  'Firehouse': 664,
#  'somethat': 665,
#  'corn': 666,
#  'boring': 667,
#  'Pizza': 668,
#  'until': 669,
#  'steak': 670,
#  'though': 671,
#  'Mediocre': 672,
#  'bit': 673,
#  'flirting': 674,
#  'fantastic': 675,
#  'velvet': 676,
#  'moz': 677,
#  'contain': 678,
#  'In': 679,
#  'establishment': 680,
#  'sides': 681,
#  'tragedy': 682,
#  'salmon': 683,
#  'unprofessional': 684,
#  'salt': 685,
#  'ratio': 686,
#  'desired': 687,
#  'Han': 688,
#  'food/service': 689,
#  'transcendant': 690,
#  'ordered': 691,
#  'An': 692,
#  'legit': 693,
#  'seemed': 694,
#  'cashier': 695,
#  'restaurants': 696,
#  'Ians': 697,
#  'reduction': 698,
#  'Dog': 699,
#  'known': 700,
#  'grilled': 701,
#  'cant': 702,
#  'movies': 703,
#  'Nargile': 704,
#  'smells': 705,
#  'kiddos': 706,
#  'warmer': 707,
#  'tap': 708,
#  'Chicken': 709,
#  'someone': 710,
#  'year': 711,
#  'too': 712,
#  'relocated': 713,
#  'pizzas': 714,
#  'handmade': 715,
#  'light': 716,
#  'bites': 717,
#  'indicate': 718,
#  'dipping': 719,
#  'toasted': 720,
#  'wine': 721,
#  'Shrimp-': 722,
#  'little': 723,
#  'familiar': 724,
#  'picture': 725,
#  'proclaimed': 726,
#  'common': 727,
#  'pulled': 728,
#  'classic': 729,
#  'high': 730,
#  'combo': 731,
#  'ever': 732,
#  'coming': 733,
#  'Risotto': 734,
#  'asking': 735,
#  'mains': 736,
#  'none': 737,
#  'paid': 738,
#  'douchey': 739,
#  'REAL': 740,
#  'At': 741,
#  'Outstanding': 742,
#  'wrapped': 743,
#  'cooked': 744,
#  'bus': 745,
#  'dollars': 746,
#  'big': 747,
#  'recommending': 748,
#  'Chinese': 749,
#  'crust': 750,
#  'kind': 751,
#  'A': 752,
#  'friends': 753,
#  'special': 754,
#  'batter': 755,
#  '17': 756,
#  'Mushroom': 757,
#  '``': 758,
#  'Sadly': 759,
#  'Roll': 760,
#  'flop': 761,
#  'Horrible': 762,
#  'suggest': 763,
#  'chefs': 764,
#  'TOLD': 765,
#  'hip': 766,
#  'unexperienced': 767,
#  'final': 768,
#  'disappointment': 769,
#  'Baseball': 770,
#  'Bachi': 771,
#  'Experience': 772,
#  'ohhh': 773,
#  'thick': 774,
#  'simply': 775,
#  'speedy': 776,
#  'Oh': 777,
#  'thing': 778,
#  'hamburger': 779,
#  'joy': 780,
#  'Overall': 781,
#  'places': 782,
#  'cocktail': 783,
#  'Thumbs': 784,
#  'breakfast': 785,
#  'homemade': 786,
#  'milk': 787,
#  'grocery': 788,
#  'honest': 789,
#  'disbelief': 790,
#  'wall': 791,
#  'Penne': 792,
#  'strings': 793,
#  'flavourful': 794,
#  'attention': 795,
#  'sergeant': 796,
#  'grill': 797,
#  '45': 798,
#  'even': 799,
#  'LEGIT': 800,
#  'pace': 801,
#  'sporting': 802,
#  'WORST': 803,
#  'Pita': 804,
#  'empty': 805,
#  'NASTY': 806,
#  'ambiance': 807,
#  'industry': 808,
#  'contained': 809,
#  'Perhaps': 810,
#  'fairly': 811,
#  'naan': 812,
#  'tender': 813,
#  'salty': 814,
#  'bread': 815,
#  'Soups': 816,
#  'over-priced': 817,
#  'postinos': 818,
#  'owners': 819,
#  'time': 820,
#  'Third': 821,
#  'Special': 822,
#  'services': 823,
#  'beef': 824,
#  'burger': 825,
#  'delightful': 826,
#  'turn': 827,
#  'hands-down': 828,
#  'vinegrette': 829,
#  'Costco': 830,
#  'waited': 831,
#  'NOT': 832,
#  'Could': 833,
#  'chocolate': 834,
#  'can': 835,
#  'delivery': 836,
#  'past': 837,
#  'couple': 838,
#  'rave': 839,
#  'wash': 840,
#  'spot': 841,
#  'right': 842,
#  'Salads': 843,
#  'Definitely': 844,
#  'mostly': 845,
#  'yet': 846,
#  'likes': 847,
#  'evening': 848,
#  '40min': 849,
#  'largely': 850,
#  'one': 851,
#  'told': 852,
#  'relax': 853,
#  'spinach': 854,
#  'rotating': 855,
#  'could': 856,
#  'due': 857,
#  'devine': 858,
#  'leaves': 859,
#  'Voodoo': 860,
#  'version': 861,
#  'guess': 862,
#  'patron': 863,
#  'HOUR': 864,
#  'lady': 865,
#  'rolls': 866,
#  'power': 867,
#  'as': 868,
#  'Wo': 869,
#  'HAD': 870,
#  'hurry': 871,
#  'word': 872,
#  'WEAK': 873,
#  'oven': 874,
#  '&': 875,
#  'Maine': 876,
#  'vegetables': 877,
#  'might': 878,
#  'downtown': 879,
#  'highlights': 880,
#  'Pricing': 881,
#  'Toast': 882,
#  'cake': 883,
#  'English': 884,
#  'breakfast/lunch': 885,
#  'recommendation': 886,
#  'juries': 887,
#  'to-go': 888,
#  'GREAT': 889,
#  'anytime': 890,
#  'Thoroughly': 891,
#  'maybe': 892,
#  'silently': 893,
#  'regular': 894,
#  '5': 895,
#  'impeccable': 896,
#  'getting': 897,
#  'works': 898,
#  'tried': 899,
#  'fair': 900,
#  'poisoning': 901,
#  'tartar': 902,
#  'downside': 903,
#  'requested': 904,
#  'wire': 905,
#  'Nicest': 906,
#  'literally': 907,
#  'experienced': 908,
#  'date': 909,
#  'rated': 910,
#  'Standard': 911,
#  'register': 912,
#  'tailored': 913,
#  'apologize': 914,
#  'another': 915,
#  'dinners': 916,
#  'compliments': 917,
#  'love': 918,
#  'reviews': 919,
#  'hair': 920,
#  'pine': 921,
#  'his': 922,
#  'summarize': 923,
#  'got': 924,
#  'venture': 925,
#  'continue': 926,
#  'man': 927,
#  'chains': 928,
#  'table': 929,
#  'place': 930,
#  'Macarons': 931,
#  'loves': 932,
#  'For': 933,
#  'actual': 934,
#  'college': 935,
#  'lot': 936,
#  'touched': 937,
#  'fuzzy': 938,
#  'coconut': 939,
#  'Ganoush': 940,
#  'nice': 941,
#  'unwrapped': 942,
#  'several': 943,
#  'Denny': 944,
#  'pork': 945,
#  'dirty-': 946,
#  'performed': 947,
#  'Server': 948,
#  'out': 949,
#  'giant': 950,
#  'handed': 951,
#  'Tucson': 952,
#  'fo': 953,
#  'dedicated': 954,
#  'accident': 955,
#  'brownish': 956,
#  'working/eating': 957,
#  'expectations': 958,
#  'rest': 959,
#  'inch': 960,
#  'Ryan': 961,
#  'provided': 962,
#  'ago': 963,
#  'NO': 964,
#  'an': 965,
#  'returned': 966,
#  'thumbs': 967,
#  'BARGAIN': 968,
#  'watched': 969,
#  'Steak': 970,
#  'Friend': 971,
#  'crowd': 972,
#  'officially': 973,
#  'unbelievable': 974,
#  'after': 975,
#  'Up': 976,
#  'hopes': 977,
#  'curry': 978,
#  'drunk': 979,
#  'ventilation': 980,
#  'bartenders': 981,
#  'of': 982,
#  'grossed': 983,
#  'certainly': 984,
#  'Hard': 985,
#  'pancakes': 986,
#  'wife': 987,
#  'name': 988,
#  'doing': 989,
#  'fucking': 990,
#  'accommodations': 991,
#  'NEVER': 992,
#  'that': 993,
#  'teeth': 994,
#  'sugary': 995,
#  'garden': 996,
#  'Steiners': 997,
#  'appetizer': 998,
#  'TOTAL': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'tastings',
#  1: 'refried',
#  2: 'six',
#  3: '3',
#  4: 'marrow',
#  5: 'fondue',
#  6: 'Awful',
#  7: 'watered',
#  8: 'article',
#  9: 'topic',
#  10: 'finish',
#  11: 'Update',
#  12: 'venturing',
#  13: 'Terrible',
#  14: 'moist',
#  15: 'temp.I',
#  16: 'Coffee',
#  17: 'strip',
#  18: 'dishes',
#  19: 'front',
#  20: 'generic',
#  21: 'double',
#  22: 'needs',
#  23: 'spaghetti',
#  24: 'easily',
#  25: 'refill',
#  26: 'fell',
#  27: 'feel',
#  28: 'tiramisu',
#  29: 'few',
#  30: 'sitting',
#  31: 'clue',
#  32: 'disgusted',
#  33: 'screwed',
#  34: 'delicious',
#  35: 'everyone',
#  36: 'The',
#  37: 'pub',
#  38: 'Bloody',
#  39: 'please',
#  40: 'Elk',
#  41: 'Sunday',
#  42: 'guys',
#  43: 'bill',
#  44: 'eating',
#  45: 'hated',
#  46: 'dealing',
#  47: 'sause',
#  48: 'point',
#  49: 'use',
#  50: 'Chipotle',
#  51: 'covers',
#  52: 'theft',
#  53: 'disgusting',
#  54: 'That',
#  55: 'charcoal',
#  56: 'gone',
#  57: 'surprised',
#  58: 'spicy',
#  59: 'Based',
#  60: 'Valley',
#  61: 'modern',
#  62: 'untoasted',
#  63: 'mushrooms',
#  64: 'beers',
#  65: 'very',
#  66: 'Burrittos',
#  67: 'falling',
#  68: 'leftover',
#  69: 'like',
#  70: 'loudly',
#  71: 'started',
#  72: 'buffets',
#  73: 'how',
#  74: 'wonderful',
#  75: 'healthy',
#  76: 'airline',
#  77: 'any',
#  78: 'brisket',
#  79: 'times',
#  80: 'tolerance',
#  81: 'talk',
#  82: 'number',
#  83: 'looking',
#  84: 'thanks',
#  85: 'Frozen',
#  86: 'yucky',
#  87: 'fill',
#  88: 'welcome',
#  89: 'Mango',
#  90: 'thought',
#  91: 'case',
#  92: 'seriously',
#  93: 'Favorite',
#  94: 'awful',
#  95: 'shocked',
#  96: 'satifying',
#  97: 'once',
#  98: 'lived',
#  99: 'really',
#  100: 'fry',
#  101: 'never',
#  102: 'ravoli',
#  103: 'fact',
#  104: 'bite',
#  105: 'wow',
#  106: 'small',
#  107: 'bamboo',
#  108: 'Yeah',
#  109: 'two',
#  110: 'yukon',
#  111: "'d",
#  112: 'hours',
#  113: 'wrong',
#  114: 'cut',
#  115: 'read',
#  116: 'EVER',
#  117: 'stood',
#  118: 'doubt',
#  119: 'this',
#  120: 'Joey',
#  121: 'Waiter',
#  122: 'cashew',
#  123: 'most',
#  124: 'three',
#  125: 'options',
#  126: 'occasions',
#  127: 'saving',
#  128: 'highlight',
#  129: 'relaxed',
#  130: 'heads',
#  131: 'us',
#  132: 'ahead',
#  133: 'bowl',
#  134: 'looked',
#  135: 'Bean',
#  136: 'ways',
#  137: 'course',
#  138: 'latte',
#  139: 'STEP',
#  140: 'neighborhood',
#  141: 'service',
#  142: 'martini',
#  143: 'list',
#  144: 'bring',
#  145: 'thin',
#  146: 'people',
#  147: 'filling',
#  148: 'refused',
#  149: 'yourself',
#  150: 'mom',
#  151: 'meat',
#  152: 'rib',
#  153: 'returning',
#  154: 'pita',
#  155: 'memory',
#  156: 'trying',
#  157: 'worst',
#  158: 'Tasted',
#  159: '.....',
#  160: 'those',
#  161: 'patio',
#  162: 'owner',
#  163: 'larger',
#  164: 'shops',
#  165: 'sound',
#  166: 'consistent',
#  167: 'tongue',
#  168: 'accountant',
#  169: 'Crust',
#  170: 'There',
#  171: 'Everyone',
#  172: 'overcooked',
#  173: 'pretty',
#  174: 'set',
#  175: 'just',
#  176: 'AZ',
#  177: 'parties',
#  178: 'blame',
#  179: 'ask',
#  180: 'last',
#  181: 'despicable',
#  182: 'towards',
#  183: 'fun',
#  184: 'consider',
#  185: 'honestly',
#  186: 'vain',
#  187: 'arepas',
#  188: 'fireball',
#  189: 'Seafood',
#  190: 'sorely',
#  191: 'business',
#  192: 'Blah',
#  193: 'i',
#  194: '-',
#  195: 'trips',
#  196: 'sexy',
#  197: 'Philadelphia',
#  198: 'Waited',
#  199: 'southwest',
#  200: 'prefer',
#  201: 'San',
#  202: 'stuff',
#  203: 'car',
#  204: 'entrees',
#  205: 'many',
#  206: 'regularly',
#  207: 'songs',
#  208: 'hospitality',
#  209: 'girlfriend',
#  210: 'daily',
#  211: 'trap',
#  212: 'WILL',
#  213: 'Both',
#  214: 'sushi',
#  215: 'Frenchman',
#  216: 'Damn',
#  217: 'mistake',
#  218: 'pissd',
#  219: 'cause',
#  220: 'rapidly',
#  221: 'Stopped',
#  222: 'quit',
#  223: 'bye',
#  224: 'food',
#  225: 'melted',
#  226: 'than',
#  227: 'jerk',
#  228: 'gloves.Everything',
#  229: 'item',
#  230: 'bathrooms',
#  231: 'tater',
#  232: 'Hut',
#  233: 'grease',
#  234: 'dead',
#  235: 'what',
#  236: 'thrilled',
#  237: 'bits',
#  238: 'whether',
#  239: 'pleasure',
#  240: 'yellow',
#  241: 'jalapeno',
#  242: 'tomato',
#  243: 'Cartel',
#  244: "'s",
#  245: 'smaller',
#  246: 'price',
#  247: 'typical',
#  248: 'saying',
#  249: 'Same',
#  250: 'pleased',
#  251: 'Breeze',
#  252: 'charge',
#  253: '30s',
#  254: 'Long',
#  255: 'law',
#  256: 'guests',
#  257: 'ESTABLISHMENT',
#  258: 'Highly',
#  259: 'sangria',
#  260: 'definitely',
#  261: 'killer',
#  262: 'Each',
#  263: 'Although',
#  264: 'terrible',
#  265: 'every',
#  266: 'Mary',
#  267: 'puree',
#  268: 'menus',
#  269: 'dough',
#  270: 'Boy',
#  271: 'vomited',
#  272: 'Gringos',
#  273: 'Camelback',
#  274: 'kid',
#  275: 'Just',
#  276: 'milkshake',
#  277: 'both',
#  278: 'flat-lined',
#  279: 'reviewing',
#  280: 'highly',
#  281: 'giving',
#  282: 'auju',
#  283: 'rate',
#  284: 'Heimer',
#  285: 'seal',
#  286: 'Things',
#  287: 'Stars',
#  288: 'melt',
#  289: 'violinists',
#  290: 'refreshing',
#  291: 'prime',
#  292: 'egg',
#  293: 'shawarrrrrrma',
#  294: 'months',
#  295: 'anyone',
#  296: 'Large',
#  297: 'classics',
#  298: 'solidify',
#  299: 'boy',
#  300: 'held',
#  301: 'Cape',
#  302: 'waste',
#  303: 'Lordy',
#  304: 'Come',
#  305: 'platter',
#  306: 'PERFECT',
#  307: 'coffee',
#  308: 'Gave',
#  309: 'excellent',
#  310: 'pop',
#  311: 'gyro',
#  312: 'apology',
#  313: 'Mmmm',
#  314: 'give',
#  315: 'Company',
#  316: 'human',
#  317: 'wants',
#  318: 'wish',
#  319: 'writing',
#  320: 'enthusiastic',
#  321: 'disrespected',
#  322: 'customer',
#  323: 'worker',
#  324: 'Palm',
#  325: 'slow',
#  326: 'servers',
#  327: 'shower',
#  328: 'joint',
#  329: 'surprise',
#  330: 'book',
#  331: 'me',
#  332: ',',
#  333: 'beat',
#  334: 'tapas',
#  335: 'dont',
#  336: 'sucker',
#  337: 'nothing',
#  338: 'new',
#  339: 'felt',
#  340: 'BBQ',
#  341: 'Dessert',
#  342: 'used',
#  343: 'hummus',
#  344: 'Any',
#  345: 'No',
#  346: 'judge',
#  347: 'inviting',
#  348: 'gas',
#  349: 'gave',
#  350: 'itself',
#  351: 'hard',
#  352: 'LOVED',
#  353: 'stomach',
#  354: 'rare',
#  355: '100',
#  356: 'fluffy',
#  357: '*',
#  358: 'ache',
#  359: 'awkwardly',
#  360: 'living',
#  361: 'tenders',
#  362: 'owner/chef',
#  363: 'vegetarian',
#  364: 'serve',
#  365: 'baklava',
#  366: 'ridiculous',
#  367: 'humiliated',
#  368: 'Cibo',
#  369: 'because',
#  370: 'summary',
#  371: 'enjoyable',
#  372: 'spotty',
#  373: 'Bouchon',
#  374: 'unique',
#  375: 'absolutley',
#  376: 'craving',
#  377: 'forty',
#  378: 'outstanding',
#  379: 'lawyers',
#  380: 'reviewer',
#  381: 'ca',
#  382: 'Grill',
#  383: 'always',
#  384: 'succulent',
#  385: 'informative',
#  386: 'fan',
#  387: 'pile',
#  388: 'Then',
#  389: 'overhaul',
#  390: 'get',
#  391: 'suggestions',
#  392: 'Jenni',
#  393: 'Extremely',
#  394: 'Salad',
#  395: 'connoisseur',
#  396: 'wave',
#  397: 'glad',
#  398: 'Casino',
#  399: 'deliciously',
#  400: 'instead',
#  401: 'Soi',
#  402: 'onion',
#  403: 'array',
#  404: 'disgrace',
#  405: 'attentive',
#  406: 'slaw',
#  407: 'Baba',
#  408: 'North',
#  409: 'climbing',
#  410: 'found',
#  411: 'frustrated',
#  412: 'Have',
#  413: 'ten',
#  414: 'hereas',
#  415: 'Kind',
#  416: 'staying',
#  417: 'Bellagio',
#  418: 'fav',
#  419: 'Mellow',
#  420: 'sashimi',
#  421: 'banana',
#  422: 'said',
#  423: 'blanket',
#  424: 'located',
#  425: 'lunch',
#  426: 'listed',
#  427: 'chef',
#  428: 'Tonight',
#  429: "'re",
#  430: 'warm',
#  431: 'trimmed',
#  432: 'worth',
#  433: 'MANAGEMENT',
#  434: 'Tried',
#  435: 'cranberry',
#  436: 'inexpensive',
#  437: 'correct',
#  438: 'WAY',
#  439: 'hit',
#  440: 'Ironman',
#  441: '15',
#  442: 'side',
#  443: 'UNREAL',
#  444: 'Gold',
#  445: 'Edinburgh',
#  446: 'Mirage',
#  447: 'AVOID',
#  448: 'be',
#  449: 'also',
#  450: 'yellowtail',
#  451: 'freaking',
#  452: 'All',
#  453: 'seasoning',
#  454: 'Food',
#  455: 'there',
#  456: 'dirt',
#  457: 'WHAT',
#  458: 'forgetting',
#  459: 'Coming',
#  460: 'Rock',
#  461: 'reasons',
#  462: 'trippy',
#  463: 'plate',
#  464: 'effort',
#  465: 'Nobu',
#  466: 'generous',
#  467: 'tough',
#  468: 'plus',
#  469: 'Left',
#  470: 'treat',
#  471: 'Buffet',
#  472: 'Wow',
#  473: 'afternoon',
#  474: 'stir',
#  475: 'sit-down',
#  476: 'style',
#  477: 'taco',
#  478: 'rowdy',
#  479: 'avocado',
#  480: 'Sushi',
#  481: 'would',
#  482: 'since',
#  483: 'saffron',
#  484: 'dripping',
#  485: 'As',
#  486: 'HAPPENED',
#  487: 'juice',
#  488: '23',
#  489: 'feels',
#  490: 'yay',
#  491: 'all',
#  492: 'themselves',
#  493: 'eel',
#  494: 'here',
#  495: 'back',
#  496: 'try',
#  497: 'takeout',
#  498: 'FREEZING',
#  499: 'close',
#  500: 'Bad',
#  501: 'lukewarm',
#  502: 'sugar',
#  503: 'nachos',
#  504: 'plastic',
#  505: 'margaritas',
#  506: 'shrimp',
#  507: 'Disappointing',
#  508: 'quick',
#  509: 'considering',
#  510: 'skimp',
#  511: 'vibe',
#  512: 'palate',
#  513: 'legs',
#  514: 'opinion',
#  515: 'High-quality',
#  516: 'Eggplant',
#  517: 'awesome',
#  518: 'cramming',
#  519: 'via',
#  520: 'WAAAAAAyyyyyyyyyy',
#  521: 'smelled',
#  522: 'My',
#  523: 'boyfriend',
#  524: 'Burger',
#  525: 'Indian',
#  526: 'life',
#  527: 'stop',
#  528: 'fries',
#  529: 'lost',
#  530: 'voted',
#  531: 'Sun',
#  532: 'club',
#  533: 'steakhouse',
#  534: 'priced',
#  535: 'meet',
#  536: 'Everything',
#  537: 'needed',
#  538: 'real',
#  539: 'donut',
#  540: 'extraordinary',
#  541: 'wontons',
#  542: 'mediocre',
#  543: 'Mexican',
#  544: '70+',
#  545: 'attitudes',
#  546: 'relleno',
#  547: 'way',
#  548: 'myself',
#  549: 'lightly',
#  550: 'friend',
#  551: 'ensued',
#  552: 'You',
#  553: 'buffet',
#  554: 'Eve',
#  555: 'they',
#  556: 'Magazine',
#  557: 'interesting',
#  558: 'sense',
#  559: 'diverse',
#  560: 'shall',
#  561: 'guacamole',
#  562: 'crusty',
#  563: 'neat',
#  564: 'pack',
#  565: 'stay',
#  566: 'menu',
#  567: 'nay',
#  568: 'neither',
#  569: 'businesses',
#  570: 'Despite',
#  571: 'convenient',
#  572: 'lil',
#  573: 'brings',
#  574: 'single',
#  575: 'particular',
#  576: 'recommend',
#  577: 'wings',
#  578: 'burned',
#  579: 'exceeding',
#  580: 'poorly',
#  581: 'Def',
#  582: 'building',
#  583: 'flavorless',
#  584: 'Caballero',
#  585: 'Be',
#  586: 'hankering',
#  587: 'gluten',
#  588: 'oil',
#  589: 'know',
#  590: 'Thai',
#  591: 'each',
#  592: 'Hawaiian',
#  593: 'Filet',
#  594: 'raspberry',
#  595: 'prepared',
#  596: 'others',
#  597: 'Pho',
#  598: 'foods',
#  599: 'profiterole',
#  600: 'chip',
#  601: 'are',
#  602: 'atmosphere.1',
#  603: 'prices',
#  604: 'do',
#  605: 'drive',
#  606: 'packed',
#  607: 'sick',
#  608: 'recall',
#  609: 'kitchen',
#  610: 'late',
#  611: 'edible',
#  612: 'andddd',
#  613: 'covered',
#  614: 'dispenser',
#  615: 'APPETIZERS',
#  616: 'WASTE',
#  617: 'avoid',
#  618: 'hungry',
#  619: '40',
#  620: 'Kabuki',
#  621: 'mesquite',
#  622: 'Why',
#  623: 'constructed',
#  624: 'believe',
#  625: 'tuna',
#  626: 'away',
#  627: 'drag',
#  628: 'Cant',
#  629: 'disappointing',
#  630: 'multiple',
#  631: 'This',
#  632: '.',
#  633: 'barely',
#  634: 'heard',
#  635: 'amazing',
#  636: 'class',
#  637: 'part',
#  638: 'shirt',
#  639: 'Maybe',
#  640: 'crispy',
#  641: 'incredible',
#  642: 'Your',
#  643: 'rinse',
#  644: 'terrific',
#  645: 'store',
#  646: 'cheek',
#  647: 'perfection',
#  648: 'good',
#  649: 'outta',
#  650: 'Bland',
#  651: 'under-services',
#  652: 'eggplant',
#  653: 'selections',
#  654: 'Ambience',
#  655: 'non-fancy',
#  656: 'station',
#  657: 'boot',
#  658: 'subpar',
#  659: 'Tigerlilly',
#  660: 'grow',
#  661: 'reasonably',
#  662: 'wait',
#  663: 'Rick',
#  664: 'Firehouse',
#  665: 'somethat',
#  666: 'corn',
#  667: 'boring',
#  668: 'Pizza',
#  669: 'until',
#  670: 'steak',
#  671: 'though',
#  672: 'Mediocre',
#  673: 'bit',
#  674: 'flirting',
#  675: 'fantastic',
#  676: 'velvet',
#  677: 'moz',
#  678: 'contain',
#  679: 'In',
#  680: 'establishment',
#  681: 'sides',
#  682: 'tragedy',
#  683: 'salmon',
#  684: 'unprofessional',
#  685: 'salt',
#  686: 'ratio',
#  687: 'desired',
#  688: 'Han',
#  689: 'food/service',
#  690: 'transcendant',
#  691: 'ordered',
#  692: 'An',
#  693: 'legit',
#  694: 'seemed',
#  695: 'cashier',
#  696: 'restaurants',
#  697: 'Ians',
#  698: 'reduction',
#  699: 'Dog',
#  700: 'known',
#  701: 'grilled',
#  702: 'cant',
#  703: 'movies',
#  704: 'Nargile',
#  705: 'smells',
#  706: 'kiddos',
#  707: 'warmer',
#  708: 'tap',
#  709: 'Chicken',
#  710: 'someone',
#  711: 'year',
#  712: 'too',
#  713: 'relocated',
#  714: 'pizzas',
#  715: 'handmade',
#  716: 'light',
#  717: 'bites',
#  718: 'indicate',
#  719: 'dipping',
#  720: 'toasted',
#  721: 'wine',
#  722: 'Shrimp-',
#  723: 'little',
#  724: 'familiar',
#  725: 'picture',
#  726: 'proclaimed',
#  727: 'common',
#  728: 'pulled',
#  729: 'classic',
#  730: 'high',
#  731: 'combo',
#  732: 'ever',
#  733: 'coming',
#  734: 'Risotto',
#  735: 'asking',
#  736: 'mains',
#  737: 'none',
#  738: 'paid',
#  739: 'douchey',
#  740: 'REAL',
#  741: 'At',
#  742: 'Outstanding',
#  743: 'wrapped',
#  744: 'cooked',
#  745: 'bus',
#  746: 'dollars',
#  747: 'big',
#  748: 'recommending',
#  749: 'Chinese',
#  750: 'crust',
#  751: 'kind',
#  752: 'A',
#  753: 'friends',
#  754: 'special',
#  755: 'batter',
#  756: '17',
#  757: 'Mushroom',
#  758: '``',
#  759: 'Sadly',
#  760: 'Roll',
#  761: 'flop',
#  762: 'Horrible',
#  763: 'suggest',
#  764: 'chefs',
#  765: 'TOLD',
#  766: 'hip',
#  767: 'unexperienced',
#  768: 'final',
#  769: 'disappointment',
#  770: 'Baseball',
#  771: 'Bachi',
#  772: 'Experience',
#  773: 'ohhh',
#  774: 'thick',
#  775: 'simply',
#  776: 'speedy',
#  777: 'Oh',
#  778: 'thing',
#  779: 'hamburger',
#  780: 'joy',
#  781: 'Overall',
#  782: 'places',
#  783: 'cocktail',
#  784: 'Thumbs',
#  785: 'breakfast',
#  786: 'homemade',
#  787: 'milk',
#  788: 'grocery',
#  789: 'honest',
#  790: 'disbelief',
#  791: 'wall',
#  792: 'Penne',
#  793: 'strings',
#  794: 'flavourful',
#  795: 'attention',
#  796: 'sergeant',
#  797: 'grill',
#  798: '45',
#  799: 'even',
#  800: 'LEGIT',
#  801: 'pace',
#  802: 'sporting',
#  803: 'WORST',
#  804: 'Pita',
#  805: 'empty',
#  806: 'NASTY',
#  807: 'ambiance',
#  808: 'industry',
#  809: 'contained',
#  810: 'Perhaps',
#  811: 'fairly',
#  812: 'naan',
#  813: 'tender',
#  814: 'salty',
#  815: 'bread',
#  816: 'Soups',
#  817: 'over-priced',
#  818: 'postinos',
#  819: 'owners',
#  820: 'time',
#  821: 'Third',
#  822: 'Special',
#  823: 'services',
#  824: 'beef',
#  825: 'burger',
#  826: 'delightful',
#  827: 'turn',
#  828: 'hands-down',
#  829: 'vinegrette',
#  830: 'Costco',
#  831: 'waited',
#  832: 'NOT',
#  833: 'Could',
#  834: 'chocolate',
#  835: 'can',
#  836: 'delivery',
#  837: 'past',
#  838: 'couple',
#  839: 'rave',
#  840: 'wash',
#  841: 'spot',
#  842: 'right',
#  843: 'Salads',
#  844: 'Definitely',
#  845: 'mostly',
#  846: 'yet',
#  847: 'likes',
#  848: 'evening',
#  849: '40min',
#  850: 'largely',
#  851: 'one',
#  852: 'told',
#  853: 'relax',
#  854: 'spinach',
#  855: 'rotating',
#  856: 'could',
#  857: 'due',
#  858: 'devine',
#  859: 'leaves',
#  860: 'Voodoo',
#  861: 'version',
#  862: 'guess',
#  863: 'patron',
#  864: 'HOUR',
#  865: 'lady',
#  866: 'rolls',
#  867: 'power',
#  868: 'as',
#  869: 'Wo',
#  870: 'HAD',
#  871: 'hurry',
#  872: 'word',
#  873: 'WEAK',
#  874: 'oven',
#  875: '&',
#  876: 'Maine',
#  877: 'vegetables',
#  878: 'might',
#  879: 'downtown',
#  880: 'highlights',
#  881: 'Pricing',
#  882: 'Toast',
#  883: 'cake',
#  884: 'English',
#  885: 'breakfast/lunch',
#  886: 'recommendation',
#  887: 'juries',
#  888: 'to-go',
#  889: 'GREAT',
#  890: 'anytime',
#  891: 'Thoroughly',
#  892: 'maybe',
#  893: 'silently',
#  894: 'regular',
#  895: '5',
#  896: 'impeccable',
#  897: 'getting',
#  898: 'works',
#  899: 'tried',
#  900: 'fair',
#  901: 'poisoning',
#  902: 'tartar',
#  903: 'downside',
#  904: 'requested',
#  905: 'wire',
#  906: 'Nicest',
#  907: 'literally',
#  908: 'experienced',
#  909: 'date',
#  910: 'rated',
#  911: 'Standard',
#  912: 'register',
#  913: 'tailored',
#  914: 'apologize',
#  915: 'another',
#  916: 'dinners',
#  917: 'compliments',
#  918: 'love',
#  919: 'reviews',
#  920: 'hair',
#  921: 'pine',
#  922: 'his',
#  923: 'summarize',
#  924: 'got',
#  925: 'venture',
#  926: 'continue',
#  927: 'man',
#  928: 'chains',
#  929: 'table',
#  930: 'place',
#  931: 'Macarons',
#  932: 'loves',
#  933: 'For',
#  934: 'actual',
#  935: 'college',
#  936: 'lot',
#  937: 'touched',
#  938: 'fuzzy',
#  939: 'coconut',
#  940: 'Ganoush',
#  941: 'nice',
#  942: 'unwrapped',
#  943: 'several',
#  944: 'Denny',
#  945: 'pork',
#  946: 'dirty-',
#  947: 'performed',
#  948: 'Server',
#  949: 'out',
#  950: 'giant',
#  951: 'handed',
#  952: 'Tucson',
#  953: 'fo',
#  954: 'dedicated',
#  955: 'accident',
#  956: 'brownish',
#  957: 'working/eating',
#  958: 'expectations',
#  959: 'rest',
#  960: 'inch',
#  961: 'Ryan',
#  962: 'provided',
#  963: 'ago',
#  964: 'NO',
#  965: 'an',
#  966: 'returned',
#  967: 'thumbs',
#  968: 'BARGAIN',
#  969: 'watched',
#  970: 'Steak',
#  971: 'Friend',
#  972: 'crowd',
#  973: 'officially',
#  974: 'unbelievable',
#  975: 'after',
#  976: 'Up',
#  977: 'hopes',
#  978: 'curry',
#  979: 'drunk',
#  980: 'ventilation',
#  981: 'bartenders',
#  982: 'of',
#  983: 'grossed',
#  984: 'certainly',
#  985: 'Hard',
#  986: 'pancakes',
#  987: 'wife',
#  988: 'name',
#  989: 'doing',
#  990: 'fucking',
#  991: 'accommodations',
#  992: 'NEVER',
#  993: 'that',
#  994: 'teeth',
#  995: 'sugary',
#  996: 'garden',
#  997: 'Steiners',
#  998: 'appetizer',
#  999: 'TOTAL',
#  ...}

# %%
word_index
# Out:
# {'Wow': 5635,
#  '...': 12307,
#  'Loved': 659,
#  'this': 12524,
#  'place': 12559,
#  '.': 12675,
#  'Crust': 6,
#  'is': 12511,
#  'not': 12621,
#  'good': 12287,
#  'Not': 11837,
#  'tasty': 9618,
#  'and': 12631,
#  'the': 12673,
#  'texture': 12604,
#  'was': 12628,
#  'just': 12636,
#  'nasty': 12156,
#  'Stopped': 3567,
#  'by': 12664,
#  'during': 10854,
#  'late': 6630,
#  'May': 25,
#  'bank': 26,
#  'holiday': 27,
#  'off': 11404,
#  'Rick': 29,
#  'Steve': 30,
#  'recommendation': 8959,
#  'loved': 8829,
#  'it': 12669,
#  'The': 12625,
#  'selection': 8973,
#  'on': 11683,
#  'menu': 11961,
#  'great': 11263,
#  'so': 11622,
#  'were': 12607,
#  'prices': 9573,
#  'Now': 11015,
#  'I': 12648,
#  'am': 11726,
#  'getting': 12334,
#  'angry': 53,
#  'want': 12247,
#  'my': 12654,
#  'damn': 7472,
#  'pho': 2971,
#  'Honeslty': 61,
#  'did': 12245,
#  "n't": 12650,
#  'taste': 10068,
#  'THAT': 66,
#  'fresh': 12403,
#  ')': 12492,
#  'potatoes': 10625,
#  'like': 12325,
#  'rubber': 74,
#  'you': 12591,
#  'could': 12140,
#  'tell': 12590,
#  'they': 12658,
#  'had': 12649,
#  'been': 12365,
#  'made': 11324,
#  'up': 12276,
#  'ahead': 84,
#  'of': 12653,
#  'time': 12668,
#  'being': 11425,
#  'kept': 12345,
#  'under': 12373,
#  'a': 12571,
#  'warmer': 91,
#  'fries': 11992,
#  'too': 12311,
#  'A': 12562,
#  'touch': 2324,
#  'Service': 8756,
#  'very': 12367,
#  'prompt': 106,
#  'Would': 8750,
#  'go': 12637,
#  'back': 12623,
#  'cashier': 8714,
#  'no': 12461,
#  'care': 3862,
#  'what': 12331,
#  'ever': 12378,
#  'to': 12671,
#  'say': 11692,
#  'still': 12359,
#  'ended': 7532,
#  'wayyy': 132,
#  'overpriced': 11903,
#  'tried': 11169,
#  'Cape': 138,
#  'Cod': 139,
#  'ravoli': 140,
#  ',': 12657,
#  'chicken': 9504,
#  'with': 12539,
#  'cranberry': 145,
#  'mmmm': 147,
#  '!': 12151,
#  'disgusted': 151,
#  'because': 11613,
#  'pretty': 12306,
#  'sure': 12411,
#  'that': 12537,
#  'human': 11424,
#  'hair': 6872,
#  'shocked': 164,
#  'signs': 167,
#  'indicate': 168,
#  'cash': 169,
#  'only': 12486,
#  'Highly': 11251,
#  'recommended': 7309,
#  'Waitress': 6357,
#  'little': 12424,
#  'slow': 11830,
#  'in': 12661,
#  'service': 12194,
#  'This': 11897,
#  'worth': 11747,
#  'your': 12554,
#  'let': 7633,
#  'alone': 192,
#  'Vegas': 11376,
#  'at': 12564,
#  'all': 12434,
#  'Burrittos': 202,
#  'Blah': 203,
#  'food': 12599,
#  'amazing': 11345,
#  'also': 11943,
#  'cute': 213,
#  'less': 218,
#  'interior': 221,
#  'beautiful': 10958,
#  'So': 10642,
#  'performed': 228,
#  'That': 8796,
#  "'s": 12317,
#  'right': 9382,
#  '.the': 234,
#  'red': 1855,
#  'velvet': 236,
#  'cake': 237,
#  '..ohhh': 239,
#  'stuff': 6272,
#  '-': 11071,
#  'They': 11504,
#  'never': 10442,
#  'brought': 11505,
#  'salad': 12577,
#  'we': 12634,
#  'asked': 11646,
#  'for': 12456,
#  'hole': 257,
#  'wall': 9177,
#  'has': 12516,
#  'Mexican': 6721,
#  'street': 264,
#  'tacos': 12096,
#  'friendly': 11956,
#  'staff': 10793,
#  'Took': 271,
#  'an': 10944,
#  'hour': 10703,
#  'get': 12064,
#  'our': 12297,
#  '4': 10563,
#  'tables': 11940,
#  'restaurant': 12430,
#  'Luke': 286,
#  'warm': 11517,
#  'Our': 8699,
#  'sever': 290,
#  'running': 11396,
#  'around': 11397,
#  'he': 9927,
#  'totally': 2602,
#  'overwhelmed': 5422,
#  'worst': 10931,
#  'salmon': 10522,
#  'sashimi': 12393,
#  'Also': 11313,
#  'there': 12656,
#  'are': 12528,
#  'combos': 310,
#  'burger': 12001,
#  'beer': 9733,
#  '23': 320,
#  'which': 12468,
#  'decent': 12171,
#  'deal': 12217,
#  'final': 331,
#  'blow': 332,
#  'found': 12570,
#  'accident': 339,
#  'be': 12227,
#  'happier': 345,
#  'seems': 11797,
#  'quick': 9815,
#  'grab': 354,
#  'bite': 8884,
#  'some': 12558,
#  'familiar': 5645,
#  'pub': 360,
#  'but': 12419,
#  'do': 12211,
#  'yourself': 11433,
#  'favor': 10356,
#  'look': 10695,
#  'elsewhere': 11334,
#  'Overall': 12614,
#  'lot': 11946,
#  'redeeming': 383,
#  'quality': 10306,
#  'inexpensive': 3467,
#  'Ample': 395,
#  'portions': 10469,
#  'Poor': 401,
#  'waiter': 12024,
#  'me': 11486,
#  'feel': 11968,
#  'stupid': 412,
#  'every': 10484,
#  'came': 12538,
#  'table': 12566,
#  'My': 12026,
#  'first': 11224,
#  'visit': 10516,
#  'Hiro': 425,
#  'delight': 428,
#  'sucks': 5365,
#  'shrimp': 10670,
#  'tender': 7770,
#  'moist': 10293,
#  'There': 11481,
#  'enough': 12652,
#  'would': 12620,
#  'drag': 448,
#  'into': 2696,
#  'establishment': 9081,
#  'again': 11813,
#  'Hard': 1178,
#  'judge': 11422,
#  'whether': 458,
#  'these': 10585,
#  'sides': 6773,
#  'grossed': 5387,
#  'out': 12666,
#  'melted': 470,
#  'styrofoam': 471,
#  'eat': 12371,
#  'fear': 480,
#  'sick': 9929,
#  'On': 11081,
#  'positive': 487,
#  'note': 6017,
#  'server': 12298,
#  'attentive': 8705,
#  'provided': 496,
#  'Frozen': 500,
#  'pucks': 501,
#  'disgust': 503,
#  'people': 11305,
#  'behind': 12259,
#  'register': 513,
#  'thing': 11463,
#  'prime': 523,
#  'rib': 524,
#  'dessert': 11336,
#  'section': 527,
#  'It': 12509,
#  'bad': 12312,
#  'generic': 538,
#  'beef': 9510,
#  'cooked': 10059,
#  'If': 12092,
#  'sandwich': 12458,
#  'any': 11840,
#  'Firehouse': 559,
#  'side': 9421,
#  'Greek': 3328,
#  'dressing': 3329,
#  'pita': 8219,
#  'hummus': 9116,
#  'refreshing': 584,
#  'We': 12388,
#  'ordered': 11063,
#  'duck': 10146,
#  'rare': 8185,
#  'pink': 594,
#  'inside': 10005,
#  'nice': 10760,
#  'char': 7448,
#  'outside': 12080,
#  'He': 7188,
#  'after': 11672,
#  'us': 12569,
#  'when': 11644,
#  'realized': 2778,
#  'husband': 12027,
#  'left': 4793,
#  'his': 11008,
#  'sunglasses': 621,
#  'Their': 11271,
#  'chow': 627,
#  'mein': 628,
#  'have': 12601,
#  'horrible': 11900,
#  'attitudes': 9317,
#  'towards': 7176,
#  'customers': 647,
#  'talk': 12249,
#  'down': 12519,
#  'each': 10577,
#  'one': 11674,
#  'enjoy': 10679,
#  'their': 11909,
#  'portion': 3479,
#  'huge': 9847,
#  'servers': 12290,
#  'wonderful': 5674,
#  'imaginative': 670,
#  'Heart': 674,
#  'Attack': 675,
#  'Grill': 676,
#  'downtown': 9823,
#  'absolutely': 11153,
#  'flat-lined': 683,
#  'excuse': 3207,
#  'much': 12267,
#  'seafood': 9341,
#  '5': 9591,
#  'strings': 695,
#  'pasta': 9143,
#  'bottom': 700,
#  'amount': 12473,
#  'sauce': 11849,
#  'over': 11721,
#  'power': 714,
#  'scallop': 938,
#  'perfectly': 6082,
#  'ripped': 729,
#  'banana': 725,
#  'petrified': 732,
#  'tasteless': 11864,
#  'At': 6521,
#  'least': 11218,
#  'think': 12633,
#  'refill': 10103,
#  'water': 10102,
#  'before': 12056,
#  'struggle': 745,
#  'wave': 747,
#  '10': 5591,
#  'minutes': 12356,
#  'receives': 756,
#  'stars': 10915,
#  'APPETIZERS': 760,
#  'cocktails': 765,
#  'handmade': 768,
#  'delicious': 10046,
#  "'d": 6388,
#  'definitely': 11668,
#  'here': 12145,
#  'glad': 4358,
#  'Great': 9832,
#  'give': 10923,
#  'military': 800,
#  'discount': 801,
#  'Always': 10816,
#  'Dos': 808,
#  'Gringos': 809,
#  'Update': 811,
#  '..went': 813,
#  'second': 6886,
#  'as': 12646,
#  'got': 11496,
#  'apparently': 831,
#  'heard': 2627,
#  'salt': 12660,
#  'batter': 1104,
#  'fish': 9686,
#  'chewy': 9357,
#  'way': 11902,
#  'finish': 11631,
#  'included': 857,
#  'tastings': 859,
#  '2': 9452,
#  'drinks': 11301,
#  'Jeff': 865,
#  'went': 11333,
#  'above': 10377,
#  'beyond': 9520,
#  'expected': 8613,
#  'Really': 875,
#  'really': 12510,
#  'rice': 8158,
#  'meh': 9868,
#  'took': 12670,
#  '30': 9442,
#  'min': 4589,
#  'milkshake': 898,
#  'nothing': 11484,
#  'more': 12472,
#  'than': 12463,
#  'chocolate': 905,
#  'milk': 906,
#  'guess': 9925,
#  'should': 12600,
#  'known': 4123,
#  'suck': 12291,
#  'Excalibur': 926,
#  'use': 6022,
#  'common': 934,
#  'sense': 935,
#  'dish': 10578,
#  'quite': 12121,
#  'appalling': 942,
#  'value': 7562,
#  'well': 11092,
#  'times': 11097,
#  'Very': 11406,
#  'Bad': 10592,
#  'Customer': 953,
#  'sweet': 11880,
#  'potato': 8269,
#  'seasoned': 8924,
#  'Today': 5253,
#  "'ve": 12188,
#  'lunch': 12342,
#  'buffet': 11971,
#  'cheated': 996,
#  'wasting': 4739,
#  'eating': 8034,
#  'opportunity': 6803,
#  'going': 11733,
#  'Rice': 1005,
#  'Company': 1007,
#  'Coming': 1009,
#  'experiencing': 1013,
#  'underwhelming': 12629,
#  'relationship': 1016,
#  'where': 9371,
#  'both': 12606,
#  'parties': 1019,
#  'ca': 12588,
#  'wait': 12293,
#  'other': 8709,
#  'person': 1170,
#  'ask': 12110,
#  'break': 12084,
#  'walked': 8609,
#  'smelled': 1038,
#  'old': 8893,
#  'grease': 8670,
#  'trap': 1043,
#  'others': 8754,
#  'turkey': 1052,
#  'roast': 7918,
#  'bland': 12551,
#  'pan': 1065,
#  'cakes': 1066,
#  'everyone': 2862,
#  'raving': 1069,
#  'about': 12219,
#  'sugary': 9656,
#  'disaster': 1075,
#  'tailored': 1076,
#  'palate': 1079,
#  'six': 11038,
#  'year': 3526,
#  'love': 11671,
#  'Pho': 7753,
#  'spring': 1092,
#  'rolls': 3107,
#  'oh': 9499,
#  'yummy': 11528,
#  'try': 7233,
#  'poor': 10365,
#  'meat': 11780,
#  'ratio': 1107,
#  'tenders': 1111,
#  'unsatisfying': 1113,
#  'All': 12432,
#  'Omelets': 1128,
#  'die': 6661,
#  'Everything': 6684,
#  'In': 12575,
#  'summary': 1141,
#  'largely': 1146,
#  'disappointing': 11330,
#  'dining': 10900,
#  'experience': 12627,
#  'sexy': 1156,
#  'party': 8996,
#  'mouth': 9363,
#  "'re": 8586,
#  'outrageously': 1165,
#  'flirting': 1166,
#  'hottest': 1169,
#  'Never': 9180,
#  'Rock': 1179,
#  'Casino': 1180,
#  'WILL': 4950,
#  'NEVER': 4951,
#  'EVER': 4952,
#  'STEP': 1186,
#  'FORWARD': 1187,
#  'IN': 1188,
#  'IT': 1189,
#  'AGAIN': 1190,
#  'Best': 10389,
#  'breakfast': 11215,
#  'bye': 1200,
#  'tip': 10419,
#  'lady': 12563,
#  "'ll": 12635,
#  'Will': 9250,
#  'Food': 12405,
#  'arrived': 7549,
#  'quickly': 8621,
#  'cafe': 6529,
#  'serves': 4296,
#  'fantastic': 9908,
#  'wife': 4753,
#  'loves': 1249,
#  'roasted': 7838,
#  'garlic': 11592,
#  'bone': 1253,
#  'marrow': 1264,
#  'added': 8989,
#  'extra': 7462,
#  'meal': 12541,
#  'another': 11423,
#  'helpful': 11958,
#  'bloddy': 1283,
#  'mary': 1284,
#  'coming': 12427,
#  'Buffet': 11289,
#  'town': 9423,
#  'price': 10654,
#  'can': 11430,
#  'beat': 12413,
#  'LOVED': 6106,
#  'mussels': 1305,
#  'wine': 11764,
#  'reduction': 1310,
#  'dishes': 10786,
#  'better': 12470,
#  'buffets': 1330,
#  'Tigerlilly': 1341,
#  'afternoon': 1346,
#  'bartender': 6679,
#  'personable': 1358,
#  'AND': 4955,
#  'ambience': 9326,
#  'music': 8501,
#  'playing': 8208,
#  'next': 12641,
#  'trip': 11541,
#  'Sooooo': 1383,
#  'REAL': 1387,
#  'sushi': 10932,
#  'lovers': 2258,
#  'honest': 8918,
#  'Yama': 1396,
#  '40min': 1404,
#  'passed': 4011,
#  'between': 5788,
#  'ordering': 1409,
#  'arriving': 1413,
#  'busy': 11930,
#  'Thai': 11204,
#  'Nice': 8847,
#  'spicy': 11884,
#  'Good': 8524,
#  'Check': 1445,
#  'gross': 4377,
#  'atmosphere': 9833,
#  'Kind': 1460,
#  'hard': 12167,
#  'mess': 1464,
#  'steak': 11443,
#  'Although': 1472,
#  'liked': 6215,
#  'sound': 1480,
#  'actual': 1486,
#  'bit': 12441,
#  'know': 12315,
#  'how': 12592,
#  'managed': 1501,
#  'served': 10107,
#  'blandest': 1505,
#  'eaten': 7422,
#  'preparing': 2517,
#  'Indian': 9112,
#  'cuisine': 1516,
#  'Worst': 11203,
#  'boot': 3470,
#  'worries': 1530,
#  'fine': 6198,
#  'waitress': 11151,
#  'guys': 1542,
#  'steaks': 7305,
#  'loving': 1550,
#  'son': 1551,
#  'who': 12253,
#  'best': 11925,
#  'places': 12369,
#  'said': 12235,
#  'thought': 11920,
#  'venture': 1579,
#  'further': 1580,
#  'away': 10359,
#  'hit': 9433,
#  'spot': 11378,
#  'night': 12058,
#  'Host': 1597,
#  'lack': 1602,
#  'word': 6621,
#  'BITCHES': 1608,
#  'Bland': 9745,
#  'liking': 1614,
#  'number': 1619,
#  'reasons': 1621,
#  'waste': 10259,
#  'reviewing..': 1632,
#  'leave': 7592,
#  'Phenomenal': 1640,
#  'ambiance': 12264,
#  'return': 12379,
#  'Definitely': 5873,
#  'venturing': 1654,
#  'strip': 1657,
#  'pork': 11792,
#  'belly': 7093,
#  'will': 12183,
#  "'m": 11451,
#  'mediocre': 11705,
#  'Penne': 1682,
#  'vodka': 1683,
#  'excellent': 10945,
#  'including': 1693,
#  'massive': 1695,
#  'meatloaf': 1696,
#  'crispy': 1700,
#  'wrap': 7635,
#  'delish': 3810,
#  'tuna': 12392,
#  'melt': 9360,
#  'burgers': 11017,
#  'management': 9316,
#  'rude': 12032,
#  'Delicious': 6179,
#  'NYC': 1719,
#  'bagels': 10991,
#  'selections': 11238,
#  'cream': 11848,
#  'cheese': 7556,
#  'real': 12020,
#  'Lox': 1729,
#  'capers': 1731,
#  'even': 12036,
#  'Subway': 12465,
#  'fact': 10555,
#  'come': 5616,
#  'meet': 1752,
#  'expectations': 1754,
#  'seriously': 11381,
#  'solid': 1760,
#  'bars': 3439,
#  'extremely': 11123,
#  'many': 11390,
#  'restaurants': 11659,
#  'dine': 4026,
#  'weekend': 1797,
#  'drink': 9447,
#  'empty': 6856,
#  'suggestions': 1813,
#  'Do': 11773,
#  'or': 12115,
#  'rarely': 6248,
#  'checked': 7646,
#  'ate': 10510,
#  'disappointed': 12593,
#  'And': 11299,
#  'curry': 2257,
#  'bamboo': 1860,
#  'shoots': 1861,
#  'blanket': 1871,
#  'moz': 1873,
#  'top': 2505,
#  'i': 11411,
#  'done': 11089,
#  'cover': 1884,
#  'subpar': 1887,
#  'bathrooms': 4392,
#  'clean': 11740,
#  'itself': 11796,
#  'decorated': 4822,
#  'always': 11955,
#  'changing': 1906,
#  '&': 9584,
#  'considering': 10450,
#  '3': 7375,
#  'pace': 10507,
#  'thumbs': 9858,
#  'watched': 10792,
#  'pay': 10724,
#  'attention': 1958,
#  'ignore': 1963,
#  'fiancé': 1967,
#  'middle': 1973,
#  'day': 10593,
#  'greeted': 7956,
#  'seated': 8007,
#  'Mandalay': 1993,
#  'Bay': 12438,
#  'waited': 7318,
#  'forty': 1999,
#  'five': 2000,
#  'vain': 2003,
#  'Crostini': 2005,
#  'stale': 9501,
#  'Some': 10710,
#  'highlights': 2015,
#  ':': 11987,
#  'nigiri': 2019,
#  'joint': 8022,
#  'different': 11083,
#  'cut': 11403,
#  'piece': 11102,
#  's': 2049,
#  'flavored': 2053,
#  'Voodoo': 2058,
#  'since': 10486,
#  'gluten': 2074,
#  'free': 2075,
#  'several': 7129,
#  'years': 7652,
#  'ago': 7653,
#  'Unfortunately': 12270,
#  'must': 11213,
#  'bakery': 6528,
#  'leftover': 2094,
#  'everything': 10833,
#  'STALE': 2101,
#  'today': 6804,
#  'relocated': 2109,
#  'impressed': 12618,
#  'immediately': 12234,
#  'diverse': 2123,
#  'reasonably': 2126,
#  'priced': 6490,
#  'Avoid': 2129,
#  'cost': 2132,
#  'Restaurant': 2134,
#  'full': 11765,
#  'DELICIOUS': 2143,
#  'hands-down': 2149,
#  'Phoenix': 9544,
#  'metro': 2160,
#  'area': 7390,
#  'if': 12647,
#  'looking': 12346,
#  'treated': 4580,
#  'Bacon': 2184,
#  'hella': 2186,
#  'salty': 2187,
#  'spinach': 2193,
#  'avocado': 2195,
#  'ingredients': 2199,
#  'sad': 11409,
#  'literally': 12495,
#  'zero': 6766,
#  'used': 11026,
#  'menus': 2225,
#  'handed': 2226,
#  'ladies': 5041,
#  'listed': 2234,
#  'waitresses': 2237,
#  'Lordy': 2242,
#  'Khao': 2245,
#  'Soi': 2246,
#  'missed': 2255,
#  'terrific': 2265,
#  'thrilled': 2270,
#  'accommodations': 2275,
#  'vegetarian': 9289,
#  'daughter': 2279,
#  'Perhaps': 2281,
#  'caught': 2283,
#  'them': 9667,
#  'judging': 2289,
#  'reviews': 12138,
#  'inspired': 2299,
#  'leaves': 2307,
#  'desired': 2312,
#  'modern': 2317,
#  'hip': 2319,
#  'while': 12085,
#  'maintaining': 2322,
#  'coziness': 2326,
#  'weekly': 2330,
#  'haunt': 2331,
#  'once': 11219,
#  'sat': 10965,
#  '20': 11127,
#  'asking': 2357,
#  'take': 8309,
#  'order': 11308,
#  'flavor': 12602,
#  'overcooked': 10032,
#  'charcoal': 10062,
#  'decided': 6896,
#  'send': 2393,
#  'looked': 5419,
#  'she': 12029,
#  'verge': 2405,
#  'having': 2407,
#  'heart': 11629,
#  'attack': 2410,
#  'dressed': 2413,
#  'rudely': 2419,
#  'probably': 10737,
#  'dirt': 9536,
#  'Love': 5989,
#  'hits': 2430,
#  'something': 11516,
#  'healthy': 10853,
#  'lacking': 12608,
#  'quantity': 2442,
#  'Lemon': 2449,
#  'raspberry': 2450,
#  'ice': 12496,
#  'cocktail': 2452,
#  'incredible': 6408,
#  'sucked': 12300,
#  'imagined': 2473,
#  'Interesting': 2475,
#  'decor': 9172,
#  'What': 12302,
#  'crepe': 2485,
#  'station': 6243,
#  'hot': 11995,
#  'bread': 11274,
#  'butter': 11283,
#  'home': 8481,
#  'chips': 11339,
#  'bacon': 9465,
#  'bits': 2503,
#  '.very': 2507,
#  'original': 2508,
#  'watch': 3049,
#  'Both': 9579,
#  'egg': 4299,
#  'When': 12479,
#  'gyros': 2539,
#  'missing': 2541,
#  'wings': 7473,
#  'feeling': 9259,
#  'satisfied': 2561,
#  'Joey': 2569,
#  'voted': 2572,
#  'dog': 9876,
#  'Valley': 8734,
#  'readers': 2580,
#  'Magazine': 2583,
#  'bowl': 5018,
#  'live': 12572,
#  'Fridays': 2601,
#  'blows': 2603,
#  'insulted': 11413,
#  'felt': 11412,
#  'disrespected': 11415,
#  'drive': 7779,
#  'things': 7355,
#  'exceeding': 2636,
#  'hope': 11490,
#  'dreamed': 2642,
#  'serivce': 2652,
#  'help': 2659,
#  'brunch': 8465,
#  'inviting': 2669,
#  'lived': 2678,
#  '1979': 2681,
#  '(': 12483,
#  'last': 10515,
#  'stepped': 2694,
#  'foot': 2695,
#  'WORST': 2701,
#  'EXPERIENCE': 2702,
#  'Must': 2705,
#  'mixed': 2720,
#  'mushrooms': 2721,
#  'yukon': 2723,
#  'gold': 2724,
#  'puree': 10225,
#  'white': 10223,
#  'corn': 2728,
#  'beateous': 2730,
#  'bug': 2757,
#  'showed': 2736,
#  'given': 3401,
#  'climbing': 2759,
#  'kitchen': 2762,
#  'For': 10858,
#  'waiting': 9063,
#  'her': 12576,
#  'soon': 12353,
#  'friend': 7707,
#  'tartar': 2793,
#  'Wo': 10298,
#  'Extremely': 2800,
#  'Tasty': 2801,
#  'though': 10175,
#  'Soggy': 2808,
#  'Jamaican': 2814,
#  'mojitos': 2815,
#  'Which': 2819,
#  'small': 10472,
#  'rich': 2832,
#  'accordingly': 2835,
#  'shower': 2852,
#  'rinse': 2846,
#  'unless': 4968,
#  'mind': 4117,
#  'nude': 2860,
#  'see': 11570,
#  'Lobster': 9905,
#  'Bisque': 4757,
#  'Bussell': 2876,
#  'Sprouts': 2877,
#  'Risotto': 2879,
#  'Filet': 8875,
#  'ALL': 2882,
#  'needed': 10100,
#  'pepper..and': 2886,
#  'course': 10896,
#  'none': 4503,
#  'Hopefully': 2896,
#  'bodes': 2898,
#  'business': 11617,
#  'someone': 12093,
#  'cook': 11441,
#  'either': 10683,
#  'cold': 12497,
#  'wrapped': 2931,
#  'dates': 2932,
#  'unbelievable': 2937,
#  'BARGAIN': 2938,
#  'folks': 7279,
#  'Otto': 2943,
#  'make': 12169,
#  'welcome': 2949,
#  'special': 9271,
#  'As': 9040,
#  '``': 12229,
#  'mains': 2957,
#  "''": 12231,
#  'uninspired': 2961,
#  'must-stop': 2985,
#  'whenever': 2986,
#  'then': 12004,
#  'dealing': 10819,
#  'world': 9128,
#  'worst/annoying': 3010,
#  'drunk': 3011,
#  'fun': 8748,
#  'chef': 8950,
#  'Ordered': 7944,
#  'double': 8369,
#  'cheeseburger': 8370,
#  'single': 10088,
#  'patty': 3027,
#  'falling': 3030,
#  'apart': 3031,
#  'picture': 3033,
#  'uploaded': 3034,
#  'Yeah': 3036,
#  'couple': 7651,
#  'sporting': 3053,
#  'events': 3054,
#  'walls': 3057,
#  'covered': 3059,
#  'TV': 3061,
#  'possible': 12162,
#  'descriptions': 3080,
#  'yum': 3084,
#  'eel': 3091,
#  'yet': 12358,
#  'mayo': 8491,
#  'NONE': 3104,
#  ...}

# %%
index_word
# Out:
# {0: 'Wow',
#  1: '...',
#  2: 'Loved',
#  3: 'this',
#  4: 'place',
#  5: '.',
#  6: 'Crust',
#  7: 'is',
#  8: 'not',
#  9: 'good',
#  10: '.',
#  11: 'Not',
#  12: 'tasty',
#  13: 'and',
#  14: 'the',
#  15: 'texture',
#  16: 'was',
#  17: 'just',
#  18: 'nasty',
#  19: '.',
#  20: 'Stopped',
#  21: 'by',
#  22: 'during',
#  23: 'the',
#  24: 'late',
#  25: 'May',
#  26: 'bank',
#  27: 'holiday',
#  28: 'off',
#  29: 'Rick',
#  30: 'Steve',
#  31: 'recommendation',
#  32: 'and',
#  33: 'loved',
#  34: 'it',
#  35: '.',
#  36: 'The',
#  37: 'selection',
#  38: 'on',
#  39: 'the',
#  40: 'menu',
#  41: 'was',
#  42: 'great',
#  43: 'and',
#  44: 'so',
#  45: 'were',
#  46: 'the',
#  47: 'prices',
#  48: '.',
#  49: 'Now',
#  50: 'I',
#  51: 'am',
#  52: 'getting',
#  53: 'angry',
#  54: 'and',
#  55: 'I',
#  56: 'want',
#  57: 'my',
#  58: 'damn',
#  59: 'pho',
#  60: '.',
#  61: 'Honeslty',
#  62: 'it',
#  63: 'did',
#  64: "n't",
#  65: 'taste',
#  66: 'THAT',
#  67: 'fresh',
#  68: '.',
#  69: ')',
#  70: 'The',
#  71: 'potatoes',
#  72: 'were',
#  73: 'like',
#  74: 'rubber',
#  75: 'and',
#  76: 'you',
#  77: 'could',
#  78: 'tell',
#  79: 'they',
#  80: 'had',
#  81: 'been',
#  82: 'made',
#  83: 'up',
#  84: 'ahead',
#  85: 'of',
#  86: 'time',
#  87: 'being',
#  88: 'kept',
#  89: 'under',
#  90: 'a',
#  91: 'warmer',
#  92: '.',
#  93: 'The',
#  94: 'fries',
#  95: 'were',
#  96: 'great',
#  97: 'too',
#  98: '.',
#  99: 'A',
#  100: 'great',
#  101: 'touch',
#  102: '.',
#  103: 'Service',
#  104: 'was',
#  105: 'very',
#  106: 'prompt',
#  107: '.',
#  108: 'Would',
#  109: 'not',
#  110: 'go',
#  111: 'back',
#  112: '.',
#  113: 'The',
#  114: 'cashier',
#  115: 'had',
#  116: 'no',
#  117: 'care',
#  118: 'what',
#  119: 'so',
#  120: 'ever',
#  121: 'on',
#  122: 'what',
#  123: 'I',
#  124: 'had',
#  125: 'to',
#  126: 'say',
#  127: 'it',
#  128: 'still',
#  129: 'ended',
#  130: 'up',
#  131: 'being',
#  132: 'wayyy',
#  133: 'overpriced',
#  134: '.',
#  135: 'I',
#  136: 'tried',
#  137: 'the',
#  138: 'Cape',
#  139: 'Cod',
#  140: 'ravoli',
#  141: ',',
#  142: 'chicken',
#  143: ',',
#  144: 'with',
#  145: 'cranberry',
#  146: '...',
#  147: 'mmmm',
#  148: '!',
#  149: 'I',
#  150: 'was',
#  151: 'disgusted',
#  152: 'because',
#  153: 'I',
#  154: 'was',
#  155: 'pretty',
#  156: 'sure',
#  157: 'that',
#  158: 'was',
#  159: 'human',
#  160: 'hair',
#  161: '.',
#  162: 'I',
#  163: 'was',
#  164: 'shocked',
#  165: 'because',
#  166: 'no',
#  167: 'signs',
#  168: 'indicate',
#  169: 'cash',
#  170: 'only',
#  171: '.',
#  172: 'Highly',
#  173: 'recommended',
#  174: '.',
#  175: 'Waitress',
#  176: 'was',
#  177: 'a',
#  178: 'little',
#  179: 'slow',
#  180: 'in',
#  181: 'service',
#  182: '.',
#  183: 'This',
#  184: 'place',
#  185: 'is',
#  186: 'not',
#  187: 'worth',
#  188: 'your',
#  189: 'time',
#  190: ',',
#  191: 'let',
#  192: 'alone',
#  193: 'Vegas',
#  194: '.',
#  195: 'did',
#  196: 'not',
#  197: 'like',
#  198: 'at',
#  199: 'all',
#  200: '.',
#  201: 'The',
#  202: 'Burrittos',
#  203: 'Blah',
#  204: '!',
#  205: 'The',
#  206: 'food',
#  207: ',',
#  208: 'amazing',
#  209: '.',
#  210: 'Service',
#  211: 'is',
#  212: 'also',
#  213: 'cute',
#  214: '.',
#  215: 'I',
#  216: 'could',
#  217: 'care',
#  218: 'less',
#  219: '...',
#  220: 'The',
#  221: 'interior',
#  222: 'is',
#  223: 'just',
#  224: 'beautiful',
#  225: '.',
#  226: 'So',
#  227: 'they',
#  228: 'performed',
#  229: '.',
#  230: 'That',
#  231: "'s",
#  232: 'right',
#  233: '...',
#  234: '.the',
#  235: 'red',
#  236: 'velvet',
#  237: 'cake',
#  238: '...',
#  239: '..ohhh',
#  240: 'this',
#  241: 'stuff',
#  242: 'is',
#  243: 'so',
#  244: 'good',
#  245: '.',
#  246: '-',
#  247: 'They',
#  248: 'never',
#  249: 'brought',
#  250: 'a',
#  251: 'salad',
#  252: 'we',
#  253: 'asked',
#  254: 'for',
#  255: '.',
#  256: 'This',
#  257: 'hole',
#  258: 'in',
#  259: 'the',
#  260: 'wall',
#  261: 'has',
#  262: 'great',
#  263: 'Mexican',
#  264: 'street',
#  265: 'tacos',
#  266: ',',
#  267: 'and',
#  268: 'friendly',
#  269: 'staff',
#  270: '.',
#  271: 'Took',
#  272: 'an',
#  273: 'hour',
#  274: 'to',
#  275: 'get',
#  276: 'our',
#  277: 'food',
#  278: 'only',
#  279: '4',
#  280: 'tables',
#  281: 'in',
#  282: 'restaurant',
#  283: 'my',
#  284: 'food',
#  285: 'was',
#  286: 'Luke',
#  287: 'warm',
#  288: ',',
#  289: 'Our',
#  290: 'sever',
#  291: 'was',
#  292: 'running',
#  293: 'around',
#  294: 'like',
#  295: 'he',
#  296: 'was',
#  297: 'totally',
#  298: 'overwhelmed',
#  299: '.',
#  300: 'The',
#  301: 'worst',
#  302: 'was',
#  303: 'the',
#  304: 'salmon',
#  305: 'sashimi',
#  306: '.',
#  307: 'Also',
#  308: 'there',
#  309: 'are',
#  310: 'combos',
#  311: 'like',
#  312: 'a',
#  313: 'burger',
#  314: ',',
#  315: 'fries',
#  316: ',',
#  317: 'and',
#  318: 'beer',
#  319: 'for',
#  320: '23',
#  321: 'which',
#  322: 'is',
#  323: 'a',
#  324: 'decent',
#  325: 'deal',
#  326: '.',
#  327: 'This',
#  328: 'was',
#  329: 'like',
#  330: 'the',
#  331: 'final',
#  332: 'blow',
#  333: '!',
#  334: 'I',
#  335: 'found',
#  336: 'this',
#  337: 'place',
#  338: 'by',
#  339: 'accident',
#  340: 'and',
#  341: 'I',
#  342: 'could',
#  343: 'not',
#  344: 'be',
#  345: 'happier',
#  346: '.',
#  347: 'seems',
#  348: 'like',
#  349: 'a',
#  350: 'good',
#  351: 'quick',
#  352: 'place',
#  353: 'to',
#  354: 'grab',
#  355: 'a',
#  356: 'bite',
#  357: 'of',
#  358: 'some',
#  359: 'familiar',
#  360: 'pub',
#  361: 'food',
#  362: ',',
#  363: 'but',
#  364: 'do',
#  365: 'yourself',
#  366: 'a',
#  367: 'favor',
#  368: 'and',
#  369: 'look',
#  370: 'elsewhere',
#  371: '.',
#  372: 'Overall',
#  373: ',',
#  374: 'I',
#  375: 'like',
#  376: 'this',
#  377: 'place',
#  378: 'a',
#  379: 'lot',
#  380: '.',
#  381: 'The',
#  382: 'only',
#  383: 'redeeming',
#  384: 'quality',
#  385: 'of',
#  386: 'the',
#  387: 'restaurant',
#  388: 'was',
#  389: 'that',
#  390: 'it',
#  391: 'was',
#  392: 'very',
#  393: 'inexpensive',
#  394: '.',
#  395: 'Ample',
#  396: 'portions',
#  397: 'and',
#  398: 'good',
#  399: 'prices',
#  400: '.',
#  401: 'Poor',
#  402: 'service',
#  403: ',',
#  404: 'the',
#  405: 'waiter',
#  406: 'made',
#  407: 'me',
#  408: 'feel',
#  409: 'like',
#  410: 'I',
#  411: 'was',
#  412: 'stupid',
#  413: 'every',
#  414: 'time',
#  415: 'he',
#  416: 'came',
#  417: 'to',
#  418: 'the',
#  419: 'table',
#  420: '.',
#  421: 'My',
#  422: 'first',
#  423: 'visit',
#  424: 'to',
#  425: 'Hiro',
#  426: 'was',
#  427: 'a',
#  428: 'delight',
#  429: '!',
#  430: 'Service',
#  431: 'sucks',
#  432: '.',
#  433: 'The',
#  434: 'shrimp',
#  435: 'tender',
#  436: 'and',
#  437: 'moist',
#  438: '.',
#  439: 'There',
#  440: 'is',
#  441: 'not',
#  442: 'a',
#  443: 'deal',
#  444: 'good',
#  445: 'enough',
#  446: 'that',
#  447: 'would',
#  448: 'drag',
#  449: 'me',
#  450: 'into',
#  451: 'that',
#  452: 'establishment',
#  453: 'again',
#  454: '.',
#  455: 'Hard',
#  456: 'to',
#  457: 'judge',
#  458: 'whether',
#  459: 'these',
#  460: 'sides',
#  461: 'were',
#  462: 'good',
#  463: 'because',
#  464: 'we',
#  465: 'were',
#  466: 'grossed',
#  467: 'out',
#  468: 'by',
#  469: 'the',
#  470: 'melted',
#  471: 'styrofoam',
#  472: 'and',
#  473: 'did',
#  474: "n't",
#  475: 'want',
#  476: 'to',
#  477: 'eat',
#  478: 'it',
#  479: 'for',
#  480: 'fear',
#  481: 'of',
#  482: 'getting',
#  483: 'sick',
#  484: '.',
#  485: 'On',
#  486: 'a',
#  487: 'positive',
#  488: 'note',
#  489: ',',
#  490: 'our',
#  491: 'server',
#  492: 'was',
#  493: 'very',
#  494: 'attentive',
#  495: 'and',
#  496: 'provided',
#  497: 'great',
#  498: 'service',
#  499: '.',
#  500: 'Frozen',
#  501: 'pucks',
#  502: 'of',
#  503: 'disgust',
#  504: ',',
#  505: 'with',
#  506: 'some',
#  507: 'of',
#  508: 'the',
#  509: 'worst',
#  510: 'people',
#  511: 'behind',
#  512: 'the',
#  513: 'register',
#  514: '.',
#  515: 'The',
#  516: 'only',
#  517: 'thing',
#  518: 'I',
#  519: 'did',
#  520: 'like',
#  521: 'was',
#  522: 'the',
#  523: 'prime',
#  524: 'rib',
#  525: 'and',
#  526: 'dessert',
#  527: 'section',
#  528: '.',
#  529: 'It',
#  530: "'s",
#  531: 'too',
#  532: 'bad',
#  533: 'the',
#  534: 'food',
#  535: 'is',
#  536: 'so',
#  537: 'damn',
#  538: 'generic',
#  539: '.',
#  540: 'The',
#  541: 'burger',
#  542: 'is',
#  543: 'good',
#  544: 'beef',
#  545: ',',
#  546: 'cooked',
#  547: 'just',
#  548: 'right',
#  549: '.',
#  550: 'If',
#  551: 'you',
#  552: 'want',
#  553: 'a',
#  554: 'sandwich',
#  555: 'just',
#  556: 'go',
#  557: 'to',
#  558: 'any',
#  559: 'Firehouse',
#  560: '!',
#  561: '!',
#  562: '!',
#  563: '!',
#  564: '!',
#  565: 'My',
#  566: 'side',
#  567: 'Greek',
#  568: 'salad',
#  569: 'with',
#  570: 'the',
#  571: 'Greek',
#  572: 'dressing',
#  573: 'was',
#  574: 'so',
#  575: 'tasty',
#  576: ',',
#  577: 'and',
#  578: 'the',
#  579: 'pita',
#  580: 'and',
#  581: 'hummus',
#  582: 'was',
#  583: 'very',
#  584: 'refreshing',
#  585: '.',
#  586: 'We',
#  587: 'ordered',
#  588: 'the',
#  589: 'duck',
#  590: 'rare',
#  591: 'and',
#  592: 'it',
#  593: 'was',
#  594: 'pink',
#  595: 'and',
#  596: 'tender',
#  597: 'on',
#  598: 'the',
#  599: 'inside',
#  600: 'with',
#  601: 'a',
#  602: 'nice',
#  603: 'char',
#  604: 'on',
#  605: 'the',
#  606: 'outside',
#  607: '.',
#  608: 'He',
#  609: 'came',
#  610: 'running',
#  611: 'after',
#  612: 'us',
#  613: 'when',
#  614: 'he',
#  615: 'realized',
#  616: 'my',
#  617: 'husband',
#  618: 'had',
#  619: 'left',
#  620: 'his',
#  621: 'sunglasses',
#  622: 'on',
#  623: 'the',
#  624: 'table',
#  625: '.',
#  626: 'Their',
#  627: 'chow',
#  628: 'mein',
#  629: 'is',
#  630: 'so',
#  631: 'good',
#  632: '!',
#  633: 'They',
#  634: 'have',
#  635: 'horrible',
#  636: 'attitudes',
#  637: 'towards',
#  638: 'customers',
#  639: ',',
#  640: 'and',
#  641: 'talk',
#  642: 'down',
#  643: 'to',
#  644: 'each',
#  645: 'one',
#  646: 'when',
#  647: 'customers',
#  648: 'do',
#  649: "n't",
#  650: 'enjoy',
#  651: 'their',
#  652: 'food',
#  653: '.',
#  654: 'The',
#  655: 'portion',
#  656: 'was',
#  657: 'huge',
#  658: '!',
#  659: 'Loved',
#  660: 'it',
#  661: '...',
#  662: 'friendly',
#  663: 'servers',
#  664: ',',
#  665: 'great',
#  666: 'food',
#  667: ',',
#  668: 'wonderful',
#  669: 'and',
#  670: 'imaginative',
#  671: 'menu',
#  672: '.',
#  673: 'The',
#  674: 'Heart',
#  675: 'Attack',
#  676: 'Grill',
#  677: 'in',
#  678: 'downtown',
#  679: 'Vegas',
#  680: 'is',
#  681: 'an',
#  682: 'absolutely',
#  683: 'flat-lined',
#  684: 'excuse',
#  685: 'for',
#  686: 'a',
#  687: 'restaurant',
#  688: '.',
#  689: 'Not',
#  690: 'much',
#  691: 'seafood',
#  692: 'and',
#  693: 'like',
#  694: '5',
#  695: 'strings',
#  696: 'of',
#  697: 'pasta',
#  698: 'at',
#  699: 'the',
#  700: 'bottom',
#  701: '.',
#  702: 'The',
#  703: 'salad',
#  704: 'had',
#  705: 'just',
#  706: 'the',
#  707: 'right',
#  708: 'amount',
#  709: 'of',
#  710: 'sauce',
#  711: 'to',
#  712: 'not',
#  713: 'over',
#  714: 'power',
#  715: 'the',
#  716: 'scallop',
#  717: ',',
#  718: 'which',
#  719: 'was',
#  720: 'perfectly',
#  721: 'cooked',
#  722: '.',
#  723: 'The',
#  724: 'ripped',
#  725: 'banana',
#  726: 'was',
#  727: 'not',
#  728: 'only',
#  729: 'ripped',
#  730: ',',
#  731: 'but',
#  732: 'petrified',
#  733: 'and',
#  734: 'tasteless',
#  735: '.',
#  736: 'At',
#  737: 'least',
#  738: 'think',
#  739: 'to',
#  740: 'refill',
#  741: 'my',
#  742: 'water',
#  743: 'before',
#  744: 'I',
#  745: 'struggle',
#  746: 'to',
#  747: 'wave',
#  748: 'you',
#  749: 'over',
#  750: 'for',
#  751: '10',
#  752: 'minutes',
#  753: '.',
#  754: 'This',
#  755: 'place',
#  756: 'receives',
#  757: 'stars',
#  758: 'for',
#  759: 'their',
#  760: 'APPETIZERS',
#  761: '!',
#  762: '!',
#  763: '!',
#  764: 'The',
#  765: 'cocktails',
#  766: 'are',
#  767: 'all',
#  768: 'handmade',
#  769: 'and',
#  770: 'delicious',
#  771: '.',
#  772: 'We',
#  773: "'d",
#  774: 'definitely',
#  775: 'go',
#  776: 'back',
#  777: 'here',
#  778: 'again',
#  779: '.',
#  780: 'We',
#  781: 'are',
#  782: 'so',
#  783: 'glad',
#  784: 'we',
#  785: 'found',
#  786: 'this',
#  787: 'place',
#  788: '.',
#  789: 'Great',
#  790: 'food',
#  791: 'and',
#  792: 'service',
#  793: ',',
#  794: 'huge',
#  795: 'portions',
#  796: 'and',
#  797: 'they',
#  798: 'give',
#  799: 'a',
#  800: 'military',
#  801: 'discount',
#  802: '.',
#  803: 'Always',
#  804: 'a',
#  805: 'great',
#  806: 'time',
#  807: 'at',
#  808: 'Dos',
#  809: 'Gringos',
#  810: '!',
#  811: 'Update',
#  812: '...',
#  813: '..went',
#  814: 'back',
#  815: 'for',
#  816: 'a',
#  817: 'second',
#  818: 'time',
#  819: 'and',
#  820: 'it',
#  821: 'was',
#  822: 'still',
#  823: 'just',
#  824: 'as',
#  825: 'amazing',
#  826: 'We',
#  827: 'got',
#  828: 'the',
#  829: 'food',
#  830: 'and',
#  831: 'apparently',
#  832: 'they',
#  833: 'have',
#  834: 'never',
#  835: 'heard',
#  836: 'of',
#  837: 'salt',
#  838: 'and',
#  839: 'the',
#  840: 'batter',
#  841: 'on',
#  842: 'the',
#  843: 'fish',
#  844: 'was',
#  845: 'chewy',
#  846: '.',
#  847: 'A',
#  848: 'great',
#  849: 'way',
#  850: 'to',
#  851: 'finish',
#  852: 'a',
#  853: 'great',
#  854: '.',
#  855: 'The',
#  856: 'deal',
#  857: 'included',
#  858: '5',
#  859: 'tastings',
#  860: 'and',
#  861: '2',
#  862: 'drinks',
#  863: ',',
#  864: 'and',
#  865: 'Jeff',
#  866: 'went',
#  867: 'above',
#  868: 'and',
#  869: 'beyond',
#  870: 'what',
#  871: 'we',
#  872: 'expected',
#  873: '.',
#  874: '-',
#  875: 'Really',
#  876: ',',
#  877: 'really',
#  878: 'good',
#  879: 'rice',
#  880: ',',
#  881: 'all',
#  882: 'the',
#  883: 'time',
#  884: '.',
#  885: 'The',
#  886: 'service',
#  887: 'was',
#  888: 'meh',
#  889: '.',
#  890: 'It',
#  891: 'took',
#  892: 'over',
#  893: '30',
#  894: 'min',
#  895: 'to',
#  896: 'get',
#  897: 'their',
#  898: 'milkshake',
#  899: ',',
#  900: 'which',
#  901: 'was',
#  902: 'nothing',
#  903: 'more',
#  904: 'than',
#  905: 'chocolate',
#  906: 'milk',
#  907: '.',
#  908: 'I',
#  909: 'guess',
#  910: 'I',
#  911: 'should',
#  912: 'have',
#  913: 'known',
#  914: 'that',
#  915: 'this',
#  916: 'place',
#  917: 'would',
#  918: 'suck',
#  919: ',',
#  920: 'because',
#  921: 'it',
#  922: 'is',
#  923: 'inside',
#  924: 'of',
#  925: 'the',
#  926: 'Excalibur',
#  927: ',',
#  928: 'but',
#  929: 'I',
#  930: 'did',
#  931: "n't",
#  932: 'use',
#  933: 'my',
#  934: 'common',
#  935: 'sense',
#  936: '.',
#  937: 'The',
#  938: 'scallop',
#  939: 'dish',
#  940: 'is',
#  941: 'quite',
#  942: 'appalling',
#  943: 'for',
#  944: 'value',
#  945: 'as',
#  946: 'well',
#  947: '.',
#  948: '2',
#  949: 'times',
#  950: '-',
#  951: 'Very',
#  952: 'Bad',
#  953: 'Customer',
#  954: 'Service',
#  955: '!',
#  956: 'The',
#  957: 'sweet',
#  958: 'potato',
#  959: 'fries',
#  960: 'were',
#  961: 'very',
#  962: 'good',
#  963: 'and',
#  964: 'seasoned',
#  965: 'well',
#  966: '.',
#  967: 'Today',
#  968: 'is',
#  969: 'the',
#  970: 'second',
#  971: 'time',
#  972: 'I',
#  973: "'ve",
#  974: 'been',
#  975: 'to',
#  976: 'their',
#  977: 'lunch',
#  978: 'buffet',
#  979: 'and',
#  980: 'it',
#  981: 'was',
#  982: 'pretty',
#  983: 'good',
#  984: '.',
#  985: 'There',
#  986: 'is',
#  987: 'so',
#  988: 'much',
#  989: 'good',
#  990: 'food',
#  991: 'in',
#  992: 'Vegas',
#  993: 'that',
#  994: 'I',
#  995: 'feel',
#  996: 'cheated',
#  997: 'for',
#  998: 'wasting',
#  999: 'an',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
